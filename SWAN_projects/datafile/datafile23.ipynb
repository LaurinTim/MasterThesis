# %%
import os
from pathlib import Path
import pandas as pd
import gbarDataLoader23 as dl
from tqdm import tqdm

# %%
dl.loadShortSummary('23_12_15')
# Out:
# RCPC files might not have been uploaded yet.
# Elena file for 23_12_15 already exists.
# 100%|██████████| 1846/1846 [00:03<00:00, 580.29it/s]
# Elena file for 23_12_15 already exists.
# LOG file for 23_12_15 already exists.
#               Time   valv_pos  mcp_pos    i_beam   wf        amp_FC  \
# 0     1.702595e+09  872451047        0  23.15789  0.0  7.014216e-09
# 1     1.702595e+09  872451047        0  23.15789  0.0 -6.414471e-09
# 2     1.702595e+09  872451047        0  23.15789  0.0 -2.777050e-09
# 3     1.702595e+09  872451047        0  23.15789  0.0  8.693960e-09
# 4     1.702595e+09  872451047        0  23.15789  0.0  5.056661e-09
# ...            ...        ...      ...       ...  ...           ...
# 1839  1.702624e+09  872451047        0  23.15789  0.0  1.092992e-08
# 1840  1.702624e+09  872451047        0  23.15789  0.0  2.044018e-08
# 1841  1.702624e+09  872451047        0  23.15789  0.0  1.596387e-08
# 1842  1.702624e+09  872451047        0  23.15789  0.0  1.484539e-08
# ...

# %%
datafile = pd.read_csv('/eos/user/l/lkoller/GBAR/data23/datafile23.txt', delimiter = '\t')

# %%
datafile[datafile['Date'] == '23_12_06'].iloc[1][7]
# Out:
# '/eos/experiment/gbar/pgunpc/data/23_12_06/PCO-SwY_exp_20_us_1701863159.464.tif'
