# %%
import sys
sys.path.append('/eos/user/l/lkoller/SWAN_projects/data analysis 2024/Data loader')
sys.path.append('/eos/user/l/lkoller/SWAN_projects/data analysis 2024/LyA/commands')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from readTrc_4CH import Trc
from tqdm import tqdm
import scipy.signal as sci
pd.set_option("display.max_columns",150)
datafile = pd.read_csv('/eos/user/l/lkoller/GBAR/data24/datafile24.txt', delimiter = '\t')

# %%
data = datafile[[True if val in [609,616,619,622,611,623] else False for val in datafile.run]]
#data = data[[True if val in [609] else False for val in data.run]]
dfm = data[data.run_mode == 2] #mixing
dfm = dfm[dfm.Positron_Waveform != 'None']
dfm = dfm[dfm.NE50_I > 7]
#dfm = dfm[[True if len(sci.find_peaks(-Trc().open(val)[1][1][1380:1480], height = 0, distance = 20, prominence = 0.15)[0]) > 0 else False for val in dfm.Positron_Waveform]]
#dfb = data[data.run_mode == 2] #background

# %%
posifm = list(dfm.Positron_Waveform)
#posifb = list(dfb.Positron_Waveform)

# %%
posim = [[0]*2502, [0]*2502, [0]*2502, [0]*2502]
#posima = [[0]*2502, [0]*2502, [0]*2502, [0]*2502]
#posib = [[0]*2502, [0]*2502, [0]*2502, [0]*2502]

for i in range(len(posifm)):
    temp_data = Trc().open(posifm[i])
    posim[0] = [val+(bal/len(posifm)) for val,bal in zip(posim[0],temp_data[1][0])]
    posim[1] = [val+(bal/len(posifm)) for val,bal in zip(posim[1],temp_data[1][1])]
    posim[2] = [val+(bal/len(posifm)) for val,bal in zip(posim[2],temp_data[1][2])]
    posim[3] = [val+(bal/len(posifm)) for val,bal in zip(posim[3],temp_data[1][3])]
    
#for i in range(len(posifm)):
#    temp_data = Trc().open(posifm[i])
#    posima[0] = [val+(bal/len(posifm)) for val,bal in zip(posima[0],temp_data[1][0])]
#    posima[1] = [val+(bal/len(posifm)) for val,bal in zip(posima[1],temp_data[1][1])]
#    posima[2] = [val+(bal/len(posifm)) for val,bal in zip(posima[2],temp_data[1][2])]
#    posima[3] = [val+(bal/len(posifm)) for val,bal in zip(posima[3],temp_data[1][3])]
    
#for i in range(len(posifb)):
#    temp_data = Trc().open(posifb[i])
#    posib[0] = [val+bal for val,bal in zip(posib[0],temp_data[1][0])]
#    posib[1] = [val+bal for val,bal in zip(posib[1],temp_data[1][1])]
#    posib[2] = [val+bal for val,bal in zip(posib[2],temp_data[1][2])]
#    posib[3] = [val+bal for val,bal in zip(posib[3],temp_data[1][3])]

# %%
#4 files from bkg runs (all 4 from run 611, none from run 623)
xl = np.linspace(0, 2501, 2502)

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[0])
plt.plot(xl, posima[0], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[1])
plt.plot(xl, posima[1], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[2])
plt.plot(xl, posima[2], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[3])
plt.plot(xl, posima[3], linewidth = 0.5, c = 'k')

# %%
#only run 622
xl = np.linspace(0, 2501, 2502)

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[0])
plt.plot(xl, posima[0], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[1])
plt.plot(xl, posima[1], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[2])
plt.plot(xl, posima[2], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[3])
plt.plot(xl, posima[3], linewidth = 0.5, c = 'k')

# %%
#only run 619
xl = np.linspace(0, 2501, 2502)

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[0])
plt.plot(xl, posima[0], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[1])
plt.plot(xl, posima[1], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[2])
plt.plot(xl, posima[2], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[3])
plt.plot(xl, posima[3], linewidth = 0.5, c = 'k')

# %%
#only run 616
xl = np.linspace(0, 2501, 2502)

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[0])
plt.plot(xl, posima[0], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[1])
plt.plot(xl, posima[1], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[2])
plt.plot(xl, posima[2], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[3])
plt.plot(xl, posima[3], linewidth = 0.5, c = 'k')

# %%
#only run 609
xl = np.linspace(0, 2501, 2502)

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[0])
plt.plot(xl, posima[0], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[1])
plt.plot(xl, posima[1], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[2])
plt.plot(xl, posima[2], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posim[3])
plt.plot(xl, posima[3], linewidth = 0.5, c = 'k')

# %%
#all mixing runs
xl = np.linspace(0, 2501, 2502)

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posima[0])
plt.plot(xl, posima[0], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posima[1])
plt.plot(xl, posima[1], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posima[2])
plt.plot(xl, posima[2], linewidth = 0.5, c = 'k')

plt.figure(figsize = (30,10))
plt.grid(alpha = 0.5)
plt.scatter(xl, posima[3])
plt.plot(xl, posima[3], linewidth = 0.5, c = 'k')
