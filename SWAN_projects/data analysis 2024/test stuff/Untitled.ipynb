# %%
import sys
sys.path.append('/eos/user/l/lkoller/SWAN_projects/data analysis 2024/LyA/commands')
sys.path.append('/eos/user/l/lkoller/SWAN_projects/data analysis 2024/Data loader')

from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from PIL import Image
from readTrc_4CH import Trc
import time
from LyAdata24 import read_df
import os

# %%
path = '/eos/experiment/gbar/pgunpc/data/24_07_07/24_07_07posi/'
fl = os.listdir(path)
fl = [val for val in fl if val[0] != '.']
fl = [path + val for val in fl]

# %%
len(fl)
# Out:
# 331

# %%
pos = 101

data = Trc().open(fl[pos])

fig = plt.figure(layout = 'tight', figsize = (30,12))
gs = GridSpec(2, 2, figure = fig)
ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[1,0])
ax4 = fig.add_subplot(gs[1,1])

for i, ax in enumerate(fig.axes):
    ax.scatter(data[0][i], data[1][i])
    ax.grid(alpha = 0.5)
    ax.set_xlabel(xlabel = 'time [us]')
    ax.set_ylabel(ylabel = 'Voltage [V]')

# %%
pos = 2

fl = ['/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720400462.872.trc', '/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720421932.853.trc', '/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720422434.761.trc']
data = Trc().open(fl[pos])

fig = plt.figure(layout = 'tight', figsize = (30,12))
gs = GridSpec(2, 2, figure = fig)
ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[1,0])
ax4 = fig.add_subplot(gs[1,1])

for i, ax in enumerate(fig.axes):
    ax.scatter(data[0][i], data[1][i])
    ax.grid(alpha = 0.5)
    ax.set_xlabel(xlabel = 'time [us]')
    ax.set_ylabel(ylabel = 'Voltage [V]')

# %%
flw = ['/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720391131.502.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720391246.691.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720391361.894.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720391476.916.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720391592.520.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720391707.708.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720391822.909.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720391937.719.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720392052.906.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720392168.498.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720392283.686.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720392398.903.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720392513.698.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720392628.916.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720392744.478.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720392859.695.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720392974.882.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720393089.678.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720393204.879.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720393320.472.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720393435.675.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720393550.861.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720393665.673.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720393780.875.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720393896.453.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720394011.656.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720394126.842.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720394241.667.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720394356.855.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720394472.449.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720394587.651.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720394702.853.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720394817.648.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720394932.836.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720395048.548.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720395163.712.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720395278.930.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720395393.724.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720395508.926.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720395624.504.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720395739.706.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720395854.908.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720395969.702.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720396084.920.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720396200.497.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720396315.701.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720396430.887.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720396545.713.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720396660.900.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720396776.477.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720396891.695.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720397006.882.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720397121.693.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720397236.879.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720397352.473.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720397467.675.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720397582.862.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720397697.672.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720397812.859.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720397928.468.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720398043.656.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720398158.857.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720398273.668.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720398388.870.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720398504.449.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720398619.635.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720398734.917.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720398849.713.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720398964.930.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720399080.508.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720399195.710.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720399310.898.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720399425.708.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720399540.909.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720399656.487.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720399771.705.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720399886.892.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720400001.702.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720400116.889.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720400232.497.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720400347.685.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720400462.872.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720400577.683.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720400692.885.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720400808.478.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720400923.665.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720401038.868.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720401153.693.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720401268.864.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720401384.459.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720401499.644.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720401614.863.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720401729.657.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720401844.859.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720401960.439.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720402075.655.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720402190.844.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720402305.706.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720402420.904.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720
trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720425969.977.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720426081.578.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720426200.368.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720426311.982.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720426426.843.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720426538.768.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720426658.758.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720426770.341.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720426881.955.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720426995.957.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720427107.540.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720427226.346.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720427337.929.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720427452.935.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720427564.841.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720427684.835.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720427796.433.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720427907.723.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720428021.709.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720428133.632.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720428252.420.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720428363.711.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720428478.913.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720428590.820.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720428710.811.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720428822.410.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720428933.701.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720429047.700.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720429159.606.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720429278.411.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720429389.703.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720429504.890.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720429616.797.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720429736.802.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720429848.387.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720429959.983.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720430073.985.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720430185.599.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720430304.389.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720430415.972.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720430530.867.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720430642.774.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720430762.764.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720430874.363.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720430985.979.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720431099.731.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720431211.629.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720431330.434.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720431441.725.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720431556.911.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720431668.833.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720431788.824.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720431900.423.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720432011.697.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720432125.699.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720432237.621.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720432356.411.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720432467.994.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720432582.903.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720432694.810.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720432814.802.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720432926.384.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720433038.000.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720433151.999.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720433263.597.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720433382.388.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720433493.986.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720433608.880.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720433720.786.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720433840.763.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720433952.378.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720434063.975.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720434177.960.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720434289.574.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720434408.364.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720434519.964.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720434634.909.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720434746.816.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720434866.808.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720434978.422.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720435089.697.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720435203.698.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720435315.605.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720435434.410.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720435545.991.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720435660.886.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720435772.792.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720435892.799.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720436004.383.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720436115.982.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720436229.967.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720436341.582.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720436460.385.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720436571.969.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720436686.863.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720436798.786.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720436918.761.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720437030.361.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720437141.960.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720437259.561.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720437373.547.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720437487.548.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720437602.751.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720437712.840.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720437826.842.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720437940.826.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720438052.750.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720438162.839.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720438275.987.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720438394.763.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720438509.966.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720438624.869.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720438746.359.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720438858.877.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720438977.950.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720439092.885.trc','/eos/experiment/gbar/pgunpc/data/24_07_08/WF1234.1720439208.353.trc']

# %%
pos = 4

lims = [5500, 6800]

data = Trc().open(flw[pos])

fig = plt.figure(layout = 'tight', figsize = (30,12))
gs = GridSpec(2, 2, figure = fig)
ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[1,0])
ax4 = fig.add_subplot(gs[1,1])

for i, ax in enumerate(fig.axes):
    ax.scatter(data[0][i], data[1][i])
    ax.grid(alpha = 0.5)
    ax.set_xlabel(xlabel = 'time [us]')
    ax.set_ylabel(ylabel = 'Voltage [V]')
    
ax3.axvline(data[0][3][5550], color = 'r')
ax3.axvline(data[0][3][6550], color = 'r')

# %%
len(data[0][0]), data[0][0][lims[1]]-data[0][0][lims[0]]
# Out:
# (12502, 1.0400000138854892e-06)

# %%
xw = [0]*len(flw)
yw = [0]*len(flw)

for i in range(len(flw)):
    temp_data = Trc().open(flw[i])
    yw[i] = sum(temp_data[1][2][lims[0]:lims[1]])
    xw[i] = temp_data[0][2][np.argmax(temp_data[1][2][lims[0]:lims[1]]) + lims[0]]

# %%
plt.figure(figsize = (20,7))
plt.grid(alpha = 0.5)
#plt.ylim(-0.006, 0.02)
plt.scatter(xw, yw)
